# %% [markdown]
# ## Cocoa Economy Data

# %%
# Imports
import panel as pn
pn.extension('plotly')
import plotly.express as px
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import numpy as np
import os
from pathlib import Path
from dotenv import load_dotenv

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Load data
cocoa_economy_data = Path('/Users/erahm/Downloads/FAOSTAT_cocoa_trade_matrix.csv')

# %%
# View a sample of the data for AAPL Historical.
cocoa_economy_data = pd.read_csv('/Users/erahm/Downloads/FAOSTAT_cocoa_trade_matrix.csv')
cocoa_economy_data
# Out:
#      Domain Code                 Domain  Reporter Country Code (FAO)  \
# 0             TM  Detailed trade matrix                           32
# 1             TM  Detailed trade matrix                           32
# 2             TM  Detailed trade matrix                           32
# 3             TM  Detailed trade matrix                           32
# 4             TM  Detailed trade matrix                           32
# ...          ...                    ...                          ...
# 1583          TM  Detailed trade matrix                          159
# 1584          TM  Detailed trade matrix                          159
# 1585          TM  Detailed trade matrix                          159
# 1586          TM  Detailed trade matrix                          159
# 1587          TM  Detailed trade matrix                          159
#
#      Reporter Countries  Partner Country Code (FAO)         Partner Countries  \
# ...

# %%
# Create Cocoa Economy Data DataFrame
cocoa_economy_data_df = pd.DataFrame(cocoa_economy_data)
cocoa_economy_data_df
# Out:
#      Domain Code                 Domain  Reporter Country Code (FAO)  \
# 0             TM  Detailed trade matrix                           32
# 1             TM  Detailed trade matrix                           32
# 2             TM  Detailed trade matrix                           32
# 3             TM  Detailed trade matrix                           32
# 4             TM  Detailed trade matrix                           32
# ...          ...                    ...                          ...
# 1583          TM  Detailed trade matrix                          159
# 1584          TM  Detailed trade matrix                          159
# 1585          TM  Detailed trade matrix                          159
# 1586          TM  Detailed trade matrix                          159
# 1587          TM  Detailed trade matrix                          159
#
#      Reporter Countries  Partner Country Code (FAO)         Partner Countries  \
# ...

# %%
#econ_path = Path('/Users', 'tylerhubbard', 'umnfintech', 'project1_group3', 'Resources', 'FAOSTAT_food_insecurity.csv')
#cocoa_economy_data_df = pd.read_csv(cocoa_economy_data , index_col=['Item', 'Area', 'Year'])
cocoa_economy_data_df = cocoa_economy_data_df.drop(columns=['Domain Code', 'Domain', 'Area Code (FAO)', 'Element Code',
                                'Item Code', 'Year Code', 'Flag', 'Flag Description', 'Element'])
                                index=['Cocoa, beans', 'Cocoa, butter', 'Cocoa, paste', 'Cocoa, powder & cake'
                                ])
cocoa_economy_data_df.head()
# Out:
#   File "C:\Users\erahm\AppData\Local\Temp/ipykernel_7652/1673830961.py", line 5
#     index=['Cocoa, beans', 'Cocoa, butter', 'Cocoa, paste', 'Cocoa, powder & cake'
#     ^
# IndentationError: unexpected indent

# %%
econ_path = Path('/Users', 'tylerhubbard', 'umnfintech', 'project1_group3', 'Resources', 'FAOSTAT_food_insecurity.csv')
econ_df = pd.read_csv(econ_path, index_col=['Item', 'Area', 'Year'])
econ_df = econ_df.drop(columns=['Domain Code', 'Domain', 'Area Code (FAO)', 'Element Code',
                                'Item Code', 'Year Code', 'Flag', 'Flag Description', 'Note', 'Element'],
                      index=['Average value of food production (constant 2004-2006 I$/cap) (3-year average)',
                      'Cereal import dependency ratio (percent) (3-year average)',
                            'Prevalence of undernourishment (percent) (3-year average)',
                            'Percent of arable land equipped for irrigation (percent) (3-year average)',
                            'Percentage of population using at least basic drinking water services (percent)',
                            'Percentage of population using safely managed drinking water services (Percent)'
                            ])
econ_df.head(60)
