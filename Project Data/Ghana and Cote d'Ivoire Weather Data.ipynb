# %% [markdown]
# # Ghana and Cote d'Ivoire Weather Data (1901-2020)

# %% [markdown]
# Source: https://climateknowledgeportal.worldbank.org/

# %%
# Imports
import panel as pn
pn.extension('plotly')
import plotly.express as px
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import numpy as np
import os
from pathlib import Path
from dotenv import load_dotenv

import warnings
warnings.filterwarnings('ignore')

# %%
# Load Ghana Annual Mean Temperature Data
ghana_annual_mean_temperature_data = Path('/Users/erahm/Downloads/Annual_Mean_Temperature_1901-2020_Ghana.csv')

# %%
# Load Cote d'Ivoire Annual Mean Temperature Data
cote_divoire_annual_mean_temperature_data = Path('/Users/erahm/Downloads/Annual_Mean_Temperature_CotedIvoire_1901_2020.csv')

# %%
# View Ghana Annual Mean Temperature Data
ghana_annual_mean_temperature_data = pd.read_csv('/Users/erahm/Downloads/Annual_Mean_Temperature_1901-2020_Ghana.csv')
ghana_annual_mean_temperature_data
# Out:
#      Year  Ghana  Ashanti  Brong Ahafo  Central  Eastern  Greater Accra  \
# 0    1901  27.07    26.57        26.94    26.70    26.63          27.34
# 1    1902  27.13    26.58        26.97    26.70    26.63          27.35
# 2    1903  27.24    26.59        27.04    26.70    26.63          27.35
# 3    1904  27.24    26.59        27.04    26.70    26.63          27.35
# 4    1905  26.95    26.40        26.78    26.60    26.44          27.19
# ..    ...    ...      ...          ...      ...      ...            ...
# 115  2016  28.23    27.61        28.03    27.73    27.67          28.39
# 116  2017  28.06    27.43        27.86    27.55    27.49          28.20
# 117  2018  27.98    27.32        27.77    27.40    27.38          28.06
# 118  2019  27.82    27.19        27.62    27.30    27.25          27.97
# 119  2020  28.12    27.46        27.92    27.57    27.53          28.23
#
#      Northern  Upper East  Upper West  Volta  Western
# ...

# %%
# Create Ghana Annual Mean Temperature DataFrame
ghana_annual_mean_temperature_df = pd.DataFrame(ghana_annual_mean_temperature_data, columns = ['Year','Ghana'])
ghana_annual_mean_temperature_df
# Out:
#      Year  Ghana
# 0    1901  27.07
# 1    1902  27.13
# 2    1903  27.24
# 3    1904  27.24
# 4    1905  26.95
# ..    ...    ...
# 115  2016  28.23
# 116  2017  28.06
# 117  2018  27.98
# 118  2019  27.82
# 119  2020  28.12
#
# [120 rows x 2 columns]

# %%
# Plot Ghana Annual Mean Temperature Data
ghana_annual_mean_temperature_df.plot(x = 'Year', y = 'Ghana', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Ghana'>

# %%
# View Cote d'Ivoire Annual Mean Temperature Data
cote_divoire_annual_mean_temperature_data = pd.read_csv('/Users/erahm/Downloads/Annual_Mean_Temperature_CotedIvoire_1901-2020.csv')
cote_divoire_annual_mean_temperature_data
# Out:
#      Year  Cote d'Ivoire  Denguele  Savanes  Vallee Du Bandama  Zanzan  Comoe  \
# 0    1901          26.47     26.28    26.71              26.63   26.78  26.63
# 1    1902          26.45     26.29    26.78              26.62   26.89  26.63
# 2    1903          26.41     26.07    26.72              26.62   26.97  26.64
# 3    1904          26.34     26.05    26.72              26.59   26.97  26.63
# 4    1905          26.35     26.03    26.63              26.55   26.79  26.60
# ..    ...            ...       ...      ...                ...     ...    ...
# 115  2016          27.26     26.86    27.62              27.55   28.00  27.65
# 116  2017          27.13     26.79    27.54              27.40   27.85  27.48
# 117  2018          26.98     26.69    27.37              27.28   27.78  27.34
# 118  2019          26.78     26.40    27.14              27.06   27.54  27.19
# 119  2020          27.13     26.76    27.53              27.46   27.96  27.49
#
# ...

# %%
# Create Cote d'Ivoire Annual Mean Temperature DataFrame
cote_divoire_annual_mean_temperature_df = pd.DataFrame(cote_divoire_annual_mean_temperature_data, columns = ['Year',"Cote d'Ivoire"])
cote_divoire_annual_mean_temperature_df
# Out:
#      Year  Cote d'Ivoire
# 0    1901          26.47
# 1    1902          26.45
# 2    1903          26.41
# 3    1904          26.34
# 4    1905          26.35
# ..    ...            ...
# 115  2016          27.26
# 116  2017          27.13
# 117  2018          26.98
# 118  2019          26.78
# 119  2020          27.13
#
# [120 rows x 2 columns]

# %%
# Plot Cote d'Ivoire Annual Mean Temperature Data
cote_divoire_annual_mean_temperature_df.plot(x = 'Year', y = "Cote d'Ivoire", kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='Year', ylabel="Cote d'Ivoire">
